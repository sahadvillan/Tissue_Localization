# %% [markdown]
# # CoTracker3: Tissue Localization with Uncertainty Quantification (UQ)
#
# This notebook sets up the CoTracker3 environment in Google Colab to perform tissue tracking using MC-Dropout for uncertainty estimation.

# %% [markdown]
# ## 1. Setup Environment

# %%
# Clone the repository
# !git clone https://github.com/facebookresearch/co-tracker
# %cd co-tracker

# Install dependencies
# !pip install -e .
# !pip install imageio[ffmpeg] flow_vis tqdm mediapy

# %% [markdown]
# ## 2. Download Model Weights

# %%
# !mkdir -p checkpoints
# !curl https://huggingface.co/facebook/cotracker3/resolve/main/scaled_online.pth -L -o checkpoints/scaled_online.pth

# %% [markdown]
# ## 3. Verify Installation
# Running a demo on the provided sample video.

# %%
# !python demo.py --checkpoint checkpoints/scaled_online.pth --video_path assets/apple.mp4 --grid_size 10

# %% [markdown]
# ## 4. Download EndoVis 2017 Dataset
# (We will add the specific download commands once the link is confirmed)

# %%
# Placeholder for EndoVis download
# !wget <dataset_link>
# !unzip <dataset_file>
